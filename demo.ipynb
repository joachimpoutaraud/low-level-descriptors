# %%
import audiofeature as af

# %%
audio_file = "audio/test.wav"

# %%
help(af)
# Out:
# Help on module audiofeature:
#
# NAME
#     audiofeature
#
# DESCRIPTION
#     This module encapsulates multiple audio feature extractors into a streamlined and modular implementation.
#     Class main properties:
#
#     - Audio file (file path)
#     - Frame size (window)
#     - Hop size (overlap length)
#
#     Features to extract:
#
#     - Amplitude envelope
#     - Root mean square
#     - Zero crossing rate
#     - Spectrograms (Linear, Log-frequency, Mel)
#
#     @author: joachimpoutaraud
#
# CLASSES
#     builtins.object
#         AudioFeature
#
#     class AudioFeature(builtins.object)
#      |  AudioFeature(audio_file, frame_size=1024, hop_size=512)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, audio_file, frame_size=1024, hop_size=512)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  amplitude_envelope(self, show=False)
#      |      Calculate amplitude envelope
# ...

# %%
demo = af.AudioFeature(audio_file)

# %%
demo.spectrograms(showLinear=True)
